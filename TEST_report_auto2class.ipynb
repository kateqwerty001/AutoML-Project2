# %%
import pandas as pd
from auto2class.auto2class import Auto2Class

data = pd.read_csv('datasets/Placement_Data_Full_Class.csv')

automl = Auto2Class(data, 'status', n_iter=[7, 7, 7])
automl.perform_model_selection()
# Out:
# ---------------Preprocessing the dataset---------------
# ---------------Extracting Day, Month and Year--------------
# ---------------Deleting redundant features--------------
# Feature: sl_no was considered as index. It will be removed.
# ---------------Handling missing values------------------
# The missing values in the feature "salary" are filled with the median value.
# ---------------Handling outliers------------------------
# 1 outliers in the feature degree_p were replaced with the median value.
# ---------------1. Encoding categorical features ------
# ---------------Transforming boolean features to int--------------
# ---------------2. Min max scaling --------------------
# ---------------3. Encode the target------------
# Target column was encoded as follows:
# {'Placed': 0, 'Not Placed': 1}
# ---------------Removing highly correlated columns ------------
# ...

# %%
automl.generate_report("PlacementData")
# Out:
# Report generated successfully.

# %%
import pandas as pdResults
from auto2class.auto2class import Auto2Class

data = pd.read_csv('datasets/weatherAUS.csv')

automl = Auto2Class(data, 'RainTomorrow', n_iter=[7, 0, 0])
automl.perform_model_selection()
# Out:
# ---------------Preprocessing the dataset---------------
# ---------------Extracting Day, Month and Year--------------
# ---------------Deleting redundant features--------------
# Feature: Date_hour has only one unique value. It will be removed.
# Feature: Date_minute has only one unique value. It will be removed.
# Feature: Date_second has only one unique value. It will be removed.
# ---------------Handling missing values------------------
# The missing values in the feature "MinTemp" are filled with the median value.
# The missing values in the feature "MaxTemp" are filled with the median value.
# The missing values in the feature "Rainfall" are filled with the median value.
# The missing values in the feature "Evaporation" are filled with the median value.
# The missing values in the feature "Sunshine" are filled with the median value.
# The missing values in the feature "WindGustDir" are filled with the most frequent value.
# ...

# %%
automl.generate_report("WeatherAustralia")
# Out:
# Report generated successfully.

# %% [markdown]
# # OLD

# %%
import pandas as pd
from auto2class.auto2class import Auto2Class

data = pd.read_csv('datasets/passanger_satisfaction.csv')
automl = Auto2Class(data, target_column_name='satisfaction', n_iter=3, n_repeats=1)

automl.perform_model_selection()
# Out:
# ---------------Preprocessing the dataset---------------
# ---------------Extracting Day, Month and Year--------------
# ---------------Deleting redundant features--------------
# Feature: Unnamed: 0 was considered as index. It will be removed.
# Feature: id was considered as index. It will be removed.
# ---------------Handling missing values------------------
# The missing values in the feature "Arrival Delay in Minutes" are filled with the median value.
# ---------------Handling outliers------------------------
# 17 outliers in the feature Age were deleted.
# 58 outliers in the feature Flight Distance were deleted.
# 3 outliers in the feature Inflight service were deleted.
# ---------------1. Encoding categorical features ------
# ---------------Transforming boolean features to int--------------
# ---------------2. Min max scaling --------------------
# ---------------3. Encode the target------------
# Target column was encoded as follows:
# ...

# %%
automl.optimizer.params_dt
# Out:
#          f1  accuracy   roc_auc clf__criterion clf__splitter clf__max_depth  \
# 0  0.945170  0.945160  0.944363           gini          best           None
# 1  0.842709  0.843776  0.842898       log_loss          best           None
# 2  0.932239  0.932374  0.965770       log_loss          best             40
# 3  0.885030  0.884638  0.921962           gini          best             10
#
#    clf__min_samples_split  clf__min_samples_leaf clf__max_features  \
# 0                       2                      1              None
# 1                      10                      2              None
# 2                       2                      4              sqrt
# 3                      10                      4              None
#
#   clf__class_weight  clf__min_impurity_decrease
# 0              None                        0.00
# 1              None                        0.10
# 2              None                        0.00
# 3              None                        0.01

# %%
automl.optimizer.params_rf
# Out:
#          f1  accuracy   roc_auc  clf__n_estimators clf__criterion  \
# 0  0.961379  0.961474  0.993575                100           gini
# 1  0.907123  0.907380  0.970280                 50           gini
# 2  0.961290  0.961377  0.993819                 50       log_loss
# 3  0.835294  0.836961  0.897222                 50       log_loss
#
#   clf__max_depth  clf__min_samples_split  clf__min_samples_leaf  \
# 0           None                       2                      1
# 1             20                       2                      1
# 2             30                       2                      1
# 3             10                      10                      4
#
#    clf__min_weight_fraction_leaf clf__max_features  clf__bootstrap
# 0                           0.00              sqrt            True
# 1                           0.01              log2            True
# 2                           0.00              None            True
# ...

# %%
automl.optimizer.params_xgb
# Out:
#          f1  accuracy   roc_auc clf__eval_metric  clf__n_estimators  \
# 0  0.960797  0.960872  0.994757             None                100
# 1  0.958980  0.959066  0.992803          logloss                 50
# 2  0.943135  0.943222  0.988238          logloss                 50
# 3  0.963158  0.963231  0.994958          logloss                100
#
#   clf__max_depth  clf__learning_rate  clf__subsample  clf__colsample_bytree  \
# 0           None                 NaN             NaN                    NaN
# 1             10                0.05             0.7                    0.7
# 2              6                0.05             0.5                    0.7
# 3             15                0.10             0.9                    0.7
#
#   clf__min_child_weight  clf__gamma clf__reg_alpha clf__reg_lambda
# 0                  None         NaN           None            None
# 1                     1         0.0              1               1
# ...

# %% [markdown]
# # COS JESZCZE RACZEJ NIC WAZNEGO

# %%
data = pd.read_csv('datasets/marketing_campaign.csv', sep='	')
automl = Auto2Class(data, target_column_name='Response', n_iter=2, n_repeats=1, metric_to_eval='f1')

automl.perform_model_selection()
# Out:
# ---------------Preprocessing the dataset---------------
# ---------------Extracting Day, Month and Year--------------
# ---------------Deleting redundant features--------------
# Feature: ID was considered as index. It will be removed.
# Feature: Dt_Customer is of type: text, not categorical. It will be removed, as our library does not support text columns.
# Feature: Z_CostContact has only one unique value. It will be removed.
# Feature: Z_Revenue has only one unique value. It will be removed.
# ---------------Handling missing values------------------
# The missing values in the feature "Income" are filled with the median value.
# ---------------Handling outliers------------------------
# 3 outliers in the feature Year_Birth were replaced with the median value.
# 8 outliers in the feature Income were replaced with the median value.
# 4 outliers in the feature NumWebPurchases were replaced with the median value.
# ...

# %% [markdown]
# ############# INNE JAKIES RZECZY

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('datasets/marketing_campaign.csv', sep='	')
data = pd.read_csv('datasets/passanger_satisfaction.csv')
data = pd.read_csv('datasets/weatherAUS.csv')
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
dataset = data.dropna(subset=['RainTomorrow'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
from auto2class.preprocessing.data_preprocessor import DataPreprocessor

preprocessed = DataPreprocessor(data, 'RainTomorrow').preprocess()
# Out:
# ---------------Preprocessing the dataset---------------
# ---------------Extracting Day, Month and Year--------------
# ---------------Deleting redundant features--------------
# Feature: Date_hour has only one unique value. It will be removed.
# Feature: Date_minute has only one unique value. It will be removed.
# Feature: Date_second has only one unique value. It will be removed.
# ---------------Handling missing values------------------
# The missing values in the feature "MinTemp" are filled with the median value.
# The missing values in the feature "MaxTemp" are filled with the median value.
# The missing values in the feature "Rainfall" are filled with the median value.
# The missing values in the feature "Evaporation" are filled with the median value.
# The missing values in the feature "Sunshine" are filled with the median value.
# The missing values in the feature "WindGustDir" are filled with the most frequent value.
# ...

# %%
# count NA
preprocessed.isna().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Date_year        0
# Date_month       0
# Date_day         0
# RainToday_No     0
# target           0
# dtype: int64

# %%
preprocessed
# Out:
#         Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       0.041667  0.535620  0.517241  0.001617     0.033103  0.586207
# 1       0.041667  0.377309  0.559387  0.000000     0.033103  0.586207
# 2       0.041667  0.522427  0.570881  0.000000     0.033103  0.586207
# 3       0.041667  0.424802  0.614943  0.000000     0.033103  0.586207
# 4       0.041667  0.643799  0.697318  0.002695     0.033103  0.586207
# ...          ...       ...       ...       ...          ...       ...
# 66300   0.395833  0.736148  0.651341  0.004852     0.099310  0.075862
# 91256   0.291667  0.680739  0.572797  0.000000     0.033103  0.586207
# 135824  0.354167  0.337731  0.371648  0.000000     0.033103  0.586207
# 49146   0.833333  0.588391  0.616858  0.000000     0.033103  0.586207
# 101489  0.458333  0.408971  0.400383  0.000000     0.012414  0.482759
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity3pm  \
# ...

# %%
from optimization.optimizer_all_models import OptimizerAllModels

optimizer = OptimizerAllModels(preprocessed, n_iter = 2, n_repeats=1, metric_to_eval='accuracy', random_state=420)
optimizer.perform_analysis()
# Out:
# ---Performing hyperparameter tuning for DecisionTreeClassifier...
# Default model results: {'f1': 0.8905297442585918, 'accuracy': 0.8909936479128857, 'roc_auc': 0.8911206525210692, 'clf__criterion': 'gini', 'clf__splitter': 'best', 'clf__max_depth': None, 'clf__min_samples_split': 2, 'clf__min_samples_leaf': 1, 'clf__max_features': None, 'clf__class_weight': None, 'clf__min_impurity_decrease': 0.0}
# Checked another model, results on train-set, using cross-validation: {'f1': 0.7913899181417818, 'accuracy': 0.7913972640032668, 'roc_auc': 0.8713262445546903}
# Checked another model, results on train-set, using cross-validation: {'f1': 0.33440519271362323, 'accuracy': 0.5009641779532203, 'roc_auc': 0.49780846881113544}
# ---Performing hyperparameter tuning for RandomForestClassifier...
# ...

# %%
optimizer.params_dt
# Out:
#          f1  accuracy   roc_auc clf__criterion clf__splitter clf__max_depth  \
# 0  0.890530  0.890994  0.891121           gini          best           None
# 1  0.791390  0.791397  0.871326           gini        random             20
# 2  0.334405  0.500964  0.497808       log_loss        random             30
#
#    clf__min_samples_split  clf__min_samples_leaf clf__max_features  \
# 0                       2                      1              None
# 1                       5                      1              log2
# 2                      10                      1              log2
#
#   clf__class_weight  clf__min_impurity_decrease
# 0              None                        0.00
# 1              None                        0.00
# 2              None                        0.05

# %%
optimizer.params_rf
# Out:
#          f1  accuracy   roc_auc  clf__n_estimators clf__criterion  \
# 0  0.933932  0.933984  0.985396                100           gini
# 1  0.905479  0.905545  0.968550                 50       log_loss
# 2  0.893477  0.893532  0.960296                 50       log_loss
#
#   clf__max_depth  clf__min_samples_split  clf__min_samples_leaf  \
# 0           None                       2                      1
# 1             20                       5                      2
# 2             20                       5                      4
#
#    clf__min_weight_fraction_leaf clf__max_features  clf__bootstrap
# 0                            0.0              sqrt            True
# 1                            0.0              log2            True
# 2                            0.0              log2            True

# %%
optimizer.params_xgb
# Out:
#          f1  accuracy   roc_auc clf__eval_metric clf__n_estimators  \
# 0  0.835921  0.835923  0.918420             None              None
# 1  0.916900  0.916979  0.969802          logloss               200
# 2  0.928596  0.928668  0.976649          logloss               200
#
#   clf__max_depth  clf__learning_rate  clf__subsample  clf__colsample_bytree  \
# 0           None                 NaN             NaN                    NaN
# 1             10                 0.2             0.5                    0.5
# 2             15                 0.1             0.5                    0.9
#
#   clf__min_child_weight  clf__gamma clf__reg_alpha clf__reg_lambda
# 0                  None         NaN           None            None
# 1                     1         0.2              1               1
# 2                     5         0.1              0               2
